# %% [markdown]
# # Clustering new real estate properties around metro stations
#
# This analysis is focused on the real estate properties currently being under construction by clustering them around metro stations to reveal perspective areas. Since the real estate properties development is growing faster than the city infrastructure the analysis can be useful for real estate marketing.

# %% [markdown]
# ### Import necessary packages

# %%
#!pip3 install seaborn
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import requests
import urllib.request
import csv
import json

# %% [markdown]
# ### Install geopy and obtain coordinates of the city center

# %%
#!pip3 install geopy
from geopy.geocoders import Nominatim
import folium 

address = 'Moscow, RUS'

geolocator = Nominatim(user_agent="my-app")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of city are {}, {}.'.format(latitude, longitude))
# Out:
# Collecting geopy
#   Downloading geopy-1.22.0-py2.py3-none-any.whl (113 kB)
#      |████████████████████████████████| 113 kB 441 kB/s eta 0:00:01
# Collecting geographiclib<2,>=1.49
#   Downloading geographiclib-1.50-py3-none-any.whl (38 kB)
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-1.50 geopy-1.22.0
# The geograpical coordinate of city are 55.7504461, 37.6174943.

# %% [markdown]
# ### Specify Foursquare credentials

# %%
# @hidden_cell
CLIENT_ID = 'ACZJOECQKRZ2W0XWIZRIOUW4YGI3030QJWHVTMVZZKLH0AMN' # your Foursquare ID
CLIENT_SECRET = 'E50W0Y52T0RTMTAQDUSMW02AFR5YANAIQIUKEY2PAGY4XP4K' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %% [markdown]
# ### Retrieve metro station category venues as a JSON file

# %%
radius = 15000
n_results = 500

# Metro stations
cat_id = '4bf58dd8d48988d1fd931735'

# beer house
url = 'https://api.foursquare.com/v2/venues/search?&categoryId={}&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
#url = 'https://api.foursquare.com/v2/venues/search?&categoryId=4bf58dd8d48988d137941735&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    #url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    cat_id,
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    n_results)
print(url)
# Out:
# https://api.foursquare.com/v2/venues/search?&categoryId=4bf58dd8d48988d1fd931735&client_id=ACZJOECQKRZ2W0XWIZRIOUW4YGI3030QJWHVTMVZZKLH0AMN&client_secret=E50W0Y52T0RTMTAQDUSMW02AFR5YANAIQIUKEY2PAGY4XP4K&v=20180605&ll=55.7504461,37.6174943&radius=15000&limit=500

# %%
results = requests.get(url).json()

# %% [markdown]
# ### Normalize JSON and check shape and indices

# %%
results['response']['venues']
venues = json_normalize(results['response']['venues'])
type(venues)
venues.shape
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
# (50, 18)

# %%
print(venues.columns)
filtered_columns = ['name', 'location.lat', 'location.lng']
venues = venues.loc[:, filtered_columns]
# Out:
# Index(['id', 'name', 'categories', 'referralId', 'hasPerk', 'location.address',
#        'location.crossStreet', 'location.lat', 'location.lng',
#        'location.labeledLatLngs', 'location.distance', 'location.postalCode',
#        'location.cc', 'location.neighborhood', 'location.city',
#        'location.state', 'location.country', 'location.formattedAddress'],
#       dtype='object')

# %%
# clean columns
venues.columns = [col.split(".")[-1] for col in venues.columns]

venues.shape
# Out:
# (50, 3)

# %%
venues.head(10)
# Out:
#                                                 name        lat        lng  \
# 0              metro Kitay-gorod (Метро Китай-город)  55.755196  37.633110
# 1        metro Krasnye Vorota (Метро Красные ворота)  55.768659  37.649220
# 2                     metro Rimskaya (Метро Римская)  55.746339  37.681594
# 3  metro Taganskaya, line 5 (Метро Таганская, кол...  55.742171  37.653771
# 4  metro Belorusskaya, line 5 (Метро Белорусская,...  55.775309  37.582662
# 5              metro Park Pobedy (Метро Парк Победы)  55.737146  37.515340
# 6                 metro Sokolniki (Метро Сокольники)  55.789241  37.680353
# 7           metro Proletarskaya (Метро Пролетарская)  55.731690  37.664911
# 8      metro Tsvetnoy Bulvar (Метро Цветной бульвар)  55.771525  37.620784
# 9  metro Kiyevskaya, line 5 (Метро Киевская, коль...  55.743576  37.566194
#
#    NumOfProp                                           Distance
# 0          7  [2.646517111137309, 2.2291379979156507, 4.0051...
# 1          1                                [24.18536943127518]
# 2          4  [2.3026298947430797, 3.3592437443124883, 2.966...
# 3          6  [0.9721151917538717, 2.605395946545784, 1.0677...
# 4          3  [0.8868113075240112, 0.6944078535655687, 2.858...
# 5          3  [0.650341560180945, 1.3758639619849287, 2.2287...
# 6          6  [3.1390731019637332, 3.2013565747439445, 2.532...
# 7         14  [3.471115459136108, 4.669467019104481, 4.78122...
# 8          4  [2.222582971142815, 3.227016102892004, 2.87044...
# 9          7  [1.7869308037017166, 1.9868626719515954, 4.799...

# %% [markdown]
# ### Create a map with the obtained metro stations

# %%
# create map of New York using latitude and longitude values
map = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for i, lat, lng, name in zip(venues.index, venues['lat'], venues['lng'], venues['name']):
    label = '{}: {}'.format(i, name.split('(')[0])
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map)  
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Find and preprocess a list of houses under construction
#
# #### We have to specify Windows-1251 encoding in order to properly read JSON values

# %%
flats = pd.read_json('data-24713-2020-06-04.json', encoding = "Windows-1251") #"ISO-8859-1")
flats.shape
# Out:
# (1579, 25)

# %%
flats.head()
filtered_columns = ['global_id', 'Coordinates', 'MainFunctional', 'AdmArea']
flats = flats.loc[:, filtered_columns]

# %%
df_clean = flats

# %%
df_clean = df_clean[df_clean.apply(lambda row: row.astype(str).str.contains('Зеленоград').any() == False, axis=1)]
df_clean
# Out:
#        global_id                      Coordinates  \
# 0      272715485  37.693324502046,55.797677127859
# 1      272715489  37.489798795354,55.626083209178
# 2      272715492  37.569607151073,55.685225196907
# 3      272715504  37.741970758303,55.690432838423
# 4      272715510  37.595682531523,55.771000504538
# ...          ...                              ...
# 1574  1037819557  37.884342235382,55.724229565696
# 1575  1037819558  37.699581107495,55.697021718182
# 1576  1037862689  37.474834237220,55.859468813591
# 1577  1037862798  37.474834237220,55.859468813591
# 1578  1037862817  37.474834237220,55.859468813591
#
#                                          MainFunctional  \
# 0                                     Подземная стоянка
# 1                                                  Храм
# 2                                        Офисное здание
# 3     Объект аварийно-спасательной службы, формирования
# 4                                             Гостиница
# ...                                                 ...
# 1574                         Объект торговли иного типа
# 1575                                           Больница
# 1576                   Многоэтажный многоквартирный дом
# 1577                   Многоэтажный многоквартирный дом
# 1578                   Многоэтажный многоквартирный дом
#
#                                                 AdmArea
# 0                    [Восточный административный округ]
# 1                 [Юго-Западный административный округ]
# 2                 [Юго-Западный административный округ]
# 3                [Юго-Восточный административный округ]
# 4                  [Центральный административный округ]
# ...                                                 ...
# 1574          [Северо-Восточный административный округ]
# 1575  [Северный административный округ, Юго-Восточны...
# 1576                  [Северный административный округ]
# 1577                  [Северный административный округ]
# 1578                  [Северный административный округ]
#
# [1541 rows x 4 columns]

# %% [markdown]
# ### Select residential developing facilities only

# %%
df_clean = df_clean[df_clean.apply(lambda row: row.astype(str).str.contains('Многоэтажный многоквартирный дом').any(), axis=1)]
df_clean.reset_index(drop=True, inplace=True)

# %%
df_clean
# Out:
#       global_id                      Coordinates  \
# 0     272726711  37.795564262836,55.761349247059
# 1     272726777  37.662497752668,55.606339142276
# 2     272726846  37.677879903019,55.642152231422
# 3     272726887  37.500611345616,55.801860524702
# 4     272726890  37.561879230614,55.879979804897
# ..          ...                              ...
# 448  1035998832  37.609481885433,55.673467591528
# 449  1037160508  37.539289973813,55.840327725186
# 450  1037862689  37.474834237220,55.859468813591
# 451  1037862798  37.474834237220,55.859468813591
# 452  1037862817  37.474834237220,55.859468813591
#
#                        MainFunctional                             AdmArea
# 0    Многоэтажный многоквартирный дом  [Восточный административный округ]
# 1    Многоэтажный многоквартирный дом      [Южный административный округ]
# 2    Многоэтажный многоквартирный дом      [Южный административный округ]
# 3    Многоэтажный многоквартирный дом   [Северный административный округ]
# 4    Многоэтажный многоквартирный дом   [Северный административный округ]
# ..                                ...                                 ...
# 448  Многоэтажный многоквартирный дом      [Южный административный округ]
# 449  Многоэтажный многоквартирный дом   [Северный административный округ]
# 450  Многоэтажный многоквартирный дом   [Северный административный округ]
# 451  Многоэтажный многоквартирный дом   [Северный административный округ]
# 452  Многоэтажный многоквартирный дом   [Северный административный округ]
#
# [453 rows x 4 columns]

# %% [markdown]
# ### Perform some data cleaning and manipulations

# %%
#df_clean[['lat','lng']] = pd.DataFrame(df_clean['Coordinates'].astype(str).str.split(expand=True), index = df_clean.index)


df_clean[['lng','lat']] = df_clean['Coordinates'].astype(str).str.split(",", expand=True)
df_clean.drop(['Coordinates'], axis=1, inplace=True)
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_clean2 = df_clean

# %% [markdown]
# ### Create a map of buildings

# %%
# create map of New York using latitude and longitude values
map = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, gid in zip(df_clean['lat'], df_clean['lng'], df_clean['global_id']):
    label = '{}'.format(name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map)  
    
    
# add markers to map
# for lat, lng, name in zip(venues['lat'], venues['lng'], venues['name']):
#     label = '{}'.format(name)
#     label = folium.Popup(label, parse_html=True)
#     folium.CircleMarker(
#         [lat, lng],
#         radius=5,
#         popup=label,
#         color='blue',
#         fill=True,
#         fill_color='#3186cc',
#         fill_opacity=0.7,
#         parse_html=False).add_to(map)      
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Create an array of initial centers

# %%
centers = np.array(venues[['lat','lng']])
centers.shape
# Out:
# (50, 2)

# %% [markdown]
# ## Perform a clusterization with pre-fixed initial centers

# %%
from sklearn.cluster import KMeans
kclusters = 50
km = KMeans(n_clusters=kclusters, init=centers, max_iter=100, n_init=1, verbose=1)
km.fit(df_clean[['lat','lng']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-79afee3f051e> in <module>
#       2 kclusters = 50
#       3 km = KMeans(n_clusters=kclusters, init=centers, max_iter=100, n_init=1, verbose=1)
# ----> 4 km.fit(df_clean[['lat','lng']])
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
#    1552         self._validate_read_indexer(
# -> 1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#    1555         return keyarr, indexer
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1638             if missing == len(indexer):
#    1639                 axis_name = self.obj._get_axis_name(axis)
# -> 1640                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1641
#    1642             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['lat', 'lng'], dtype='object')] are in the [columns]"

# %%
km.labels_
# Out:
# array([19, 29, 29, 20, 49, 35, 29, 15, 22,  9, 45, 26, 29,  8, 25, 11, 29,
#        47, 26,  0, 29, 49, 29, 19, 29, 29, 29, 29,  7, 26, 39, 34,  9, 36,
#        16, 44, 44, 30, 30, 30, 44,  9,  0, 48, 40, 14, 45, 32, 27, 44, 44,
#         3, 26, 14, 44,  9,  2, 39, 26, 11, 36, 12, 29, 38,  8,  0, 47, 45,
#        39, 22,  8, 45,  8, 48, 34, 11,  6, 26, 45, 45, 45, 44, 47, 26, 13,
#        24, 47, 47, 37, 46, 49,  6, 36, 39, 15, 15,  3, 23, 41, 15, 47, 41,
#         7, 37, 11, 49, 37, 38, 33, 33, 24, 37, 33, 33, 37,  7, 49, 21, 49,
#        44, 47, 22, 11, 35, 33, 13, 38, 32, 33, 46,  0,  5, 22,  7, 25, 15,
#        15, 40, 24, 39, 49, 38, 46, 49,  7,  6, 37, 11, 36, 49, 25,  2, 24,
#        15, 20, 37, 22, 15,  6, 37, 12, 44, 39, 36, 42, 18, 14, 27, 38, 48,
#        17,  7, 42, 47, 46, 37,  7, 36,  0, 39, 37, 37, 23, 15, 25, 36, 22,
#         7, 37, 35, 36, 39, 41, 33, 37, 18, 18,  7, 39, 46, 30, 37, 40, 37,
#        33, 28, 18, 39,  0, 46, 48,  3, 43, 20, 33, 37, 42, 42, 18,  7, 48,
#         4,  9,  9,  7, 28, 15, 37, 20, 37, 47,  7, 37, 38, 42, 10, 42, 16,
#         2, 39, 30, 37, 39, 46, 39, 37, 15, 37, 30, 23, 48, 37, 33, 32, 46,
#        35,  2, 15, 35, 30, 37, 15, 37, 36, 22, 47, 11, 44,  3, 25, 37, 22,
#        34, 20, 44, 21, 37, 12, 47, 33, 30, 49, 37, 27, 15,  4, 49,  5, 39,
#        46, 37,  6, 30, 16, 37, 33, 22,  7, 48, 41, 11, 37, 20,  9, 37, 11,
#        37, 40, 38, 49, 20, 22,  4, 26, 30, 46, 36, 25, 39, 22, 45, 34, 49,
#        34, 36, 20, 22, 48, 29, 15, 34, 31, 38, 18, 40, 34, 34, 23, 21, 33,
#        36, 17, 45, 31, 37, 15, 37, 22, 34, 45, 31, 36, 34, 21, 17, 34, 43,
#        22, 21, 19, 31, 36, 19, 44, 34, 37, 16, 29,  5, 36, 17, 36, 46, 34,
#        22, 29, 36, 38, 29, 31, 37, 28,  1, 29,  0, 34, 48, 43, 17, 21, 47,
#        36, 21, 36, 31, 45, 34, 29, 17, 14,  3, 40, 29, 41, 25, 19, 33, 25,
#        19, 29, 21, 34, 13, 22, 12, 13, 22, 33, 49, 46, 46, 48, 37, 13,  7,
#        13, 48, 49, 46, 22, 37, 25, 41, 41, 41, 30, 20,  3, 12, 37, 18,  6,
#        40, 42, 21, 37, 42, 13, 40, 14, 48, 48, 48], dtype=int32)

# %%
df_clean['class'] = km.labels_
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### Derive some clusterization parameters

# %%
km.inertia_
# Out:
# 0.12960449689522138

# %%
km.score(df_clean[['lat','lng']])
# Out:
# -0.1296044968952213

# %% [markdown]
# ### Plot a map of clusters

# %%
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, cluster in zip(df_clean['lat'], df_clean['lng'], df_clean['class']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
# add markers to map
for i, lat, lng, name in zip(venues.index, venues['lat'], venues['lng'], venues['name']):
    label = '{}: {}'.format(i, name.split("(")[0])
    
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_clusters)             
        
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
metro = venues
metro2 = venues
df_clean.dtypes
df_clean = df_clean.astype({'lat': 'float64', 'lng': 'float64'})
df_clean.dtypes
# Out:
# global_id           int64
# MainFunctional     object
# AdmArea            object
# lng               float64
# lat               float64
# class               int32
# dtype: object

# %% [markdown]
# ### Calculate Haversine distance between two points (Earth sphericity can be negligible within particular city so Euclidean distance can be used instead)

# %%
from sklearn.metrics.pairwise import haversine_distances
from math import radians

# %%
num = []
dist = []
for st in metro.index:
    count = 0
    loc_dist = []
    for prop in df_clean.index: #['class']:
        if st == df_clean.loc[prop, 'class']:
            count+=1
            #print("{}:{}".format(metro.iloc[st,'lat'], df_clean.loc[st,'lat']))
            #print("{} {} {} {}".format(metro.loc[st,'lng'], metro.loc[st,'lat'], df_clean.loc[prop,'lng'], df_clean.loc[prop,'lat']))
            #loc_dist.append(haversine(metro.loc[st,'lng'], metro.loc[st,'lat'], df_clean.loc[st,'lng'], df_clean.loc[st,'lat']))
            #metro.loc[st,'lat']-df_clean.loc[st,'lat'])
            mtr = [metro.loc[st,'lat'], metro.loc[st,'lng']]
            pty = [df_clean.loc[prop,'lat'], df_clean.loc[prop,'lng']]
            mtr_rad = [radians(_) for _ in mtr]
            pty_rad = [radians(_) for _ in pty]
            result = haversine_distances([mtr_rad, pty_rad])[0,1]
            loc_dist.append(result*6371000/1000)
    
    num.append(count)
    dist.append(loc_dist)
#print(num)
#print(dist)
metro['NumOfProp'] = num
metro['Distance'] = dist

# %%
metro.head()
# Out:
#                                                 name        lat        lng  \
# 0              metro Kitay-gorod (Метро Китай-город)  55.755196  37.633110
# 1        metro Krasnye Vorota (Метро Красные ворота)  55.768659  37.649220
# 2                     metro Rimskaya (Метро Римская)  55.746339  37.681594
# 3  metro Taganskaya, line 5 (Метро Таганская, кол...  55.742171  37.653771
# 4  metro Belorusskaya, line 5 (Метро Белорусская,...  55.775309  37.582662
#
#    NumOfProp                                           Distance
# 0          7  [2.646517111137309, 2.2291379979156507, 4.0051...
# 1          1                                [24.18536943127518]
# 2          4  [2.3026298947430797, 3.3592437443124883, 2.966...
# 3          6  [0.9721151917538717, 2.605395946545784, 1.0677...
# 4          3  [0.8868113075240112, 0.6944078535655687, 2.858...

# %% [markdown]
# ### Calculate number of buildings within a cluster

# %%
fig0 = plt.figure(figsize=(17,8))
#clust_size = sns.barplot(data=metro.loc[metro.index, 'NumOfProp'])

clust_size = metro.loc[metro.index,'NumOfProp']
clust_size.plot(kind='bar')
plt.title('')
plt.xlabel('Clusters')
plt.ylabel('Number of buildings')

#clust_size.set_ylabel('Distance (km)')
#xticklabels=range(0,50)
#clust_size.set_xticklabels(xticklabels)
fig0.show()
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   del sys.path[0]

# %%
print('Average number of buildings in a cluster: {} +/- {}'.format(clust_size.mean(), clust_size.std()))
# Out:
# Average number of buildings in a cluster: 9.06 +/- 6.723124880832224

# %% [markdown]
# ### Plot a distince distribution between buildings and metro stations

# %%
import seaborn as sns
fig1 = plt.figure(figsize=(17,10))
ax = sns.boxplot(data=metro['Distance'])
ax.set_title('')
ax.set_xlabel('Clusters')
ax.set_ylabel('Distance (km)')
xticklabels=range(0,50)
ax.set_xticklabels(xticklabels)
fig1.get_axes()[0].set_yscale('log')
fig1.show()
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# ## Perform clasterization with random initialization

# %%
kclusters = 50
km2 = KMeans(n_clusters=kclusters, init='random', max_iter=100, n_init=100, verbose=1)
km2.fit(df_clean2[['lat','lng']])
# Out:
# Initialization complete
# Iteration 0, inertia 0.3259308489903723
# Iteration 1, inertia 0.19955153066922948
# Iteration 2, inertia 0.16637824369796173
# Iteration 3, inertia 0.14128571616326566
# Iteration 4, inertia 0.13475854956186842
# Iteration 5, inertia 0.1328313583080086
# Iteration 6, inertia 0.13159864398540833
# Iteration 7, inertia 0.13085951108206706
# Iteration 8, inertia 0.12876256916148432
# Iteration 9, inertia 0.12634908579691803
# Iteration 10, inertia 0.12589268193745626
# Converged at iteration 10: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.3360662444818289
# Iteration 1, inertia 0.17385119104927746
# Iteration 2, inertia 0.14350674523719043
# Iteration 3, inertia 0.12855571521517323
# Iteration 4, inertia 0.12380328162699997
# Iteration 5, inertia 0.12209943303720669
# Iteration 6, inertia 0.12102983211708536
# Iteration 7, inertia 0.12013347736397073
# Iteration 8, inertia 0.11991353429989826
# Iteration 9, inertia 0.11980865788152378
# Converged at iteration 9: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.2487456887838683
# Iteration 1, inertia 0.1577098699180422
# Iteration 2, inertia 0.1426103333522478
# Iteration 3, inertia 0.1374985966579095
# Iteration 4, inertia 0.1343536119183255
# Iteration 5, inertia 0.133255604072887
# Iteration 6, inertia 0.13248363095783802
# Iteration 7, inertia 0.1322147833134545
# Converged at iteration 7: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.3734978140494576
# Iteration 1, inertia 0.1794474813532431
# Iteration 2, inertia 0.1567264069509191
# Iteration 3, inertia 0.14870346951940647
# Iteration 4, inertia 0.14358318211346704
# Iteration 5, inertia 0.14197784283193657
# Iteration 6, inertia 0.14028832531884808
# Iteration 7, inertia 0.13962949771304256
# Iteration 8, inertia 0.13864568341116873
# Converged at iteration 8: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.37276112918894694
# Iteration 1, inertia 0.2126205252336851
# Iteration 2, inertia 0.18235637182872894
# Iteration 3, inertia 0.16938676380061055
# Iteration 4, inertia 0.1640113486649912
# Iteration 5, inertia 0.14645710899799927
# Iteration 6, inertia 0.1338027291590014
# Iteration 7, inertia 0.13206515019826207
# Iteration 8, inertia 0.13132220416280163
# Iteration 9, inertia 0.13064644900781835
# Converged at iteration 9: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.6219616861696962
# Iteration 1, inertia 0.22903314466855315
# Iteration 2, inertia 0.15393624472933248
# Iteration 3, inertia 0.14298821728372058
# Iteration 4, inertia 0.13966368623675915
# Iteration 5, inertia 0.13831179838292343
# Iteration 6, inertia 0.13644894866427265
# Iteration 7, inertia 0.13566341986027758
# Iteration 8, inertia 0.1350376338716717
# Converged at iteration 8: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.6469579205728083
# Iteration 1, inertia 0.2399450865556162
# Iteration 2, inertia 0.18068886558979563
# Iteration 3, inertia 0.15137763060417175
# Iteration 4, inertia 0.14388071100343428
# Iteration 5, inertia 0.1419227195878933
# Iteration 6, inertia 0.1400929204717728
# Iteration 7, inertia 0.13889713695907097
# Iteration 8, inertia 0.13778260451644161
# Iteration 9, inertia 0.13676343475725694
# Iteration 10, inertia 0.13540304551655308
# Iteration 11, inertia 0.13524491597616545
# Converged at iteration 11: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.4213958385141937
# Iteration 1, inertia 0.15477318459516545
# Iteration 2, inertia 0.12479609369896401
# Iteration 3, inertia 0.11653577041096301
# Iteration 4, inertia 0.11467759489073563
# Iteration 5, inertia 0.11414773418487939
# Converged at iteration 5: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.4008408767446994
# Iteration 1, inertia 0.18900569340036674
# Iteration 2, inertia 0.13962491092125776
# Iteration 3, inertia 0.12770741129704624
# Iteration 4, inertia 0.12310910992076209
# Iteration 5, inertia 0.12171071261994734
# Converged at iteration 5: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.3455000772194745
# Iteration 1, inertia 0.19056155143354345
# Iteration 2, inertia 0.163902150776983
# Iteration 3, inertia 0.15404126232317614
# Iteration 4, inertia 0.1458521303682794
# Iteration 5, inertia 0.14445981429647145
# Iteration 6, inertia 0.14389102890510624
# Iteration 7, inertia 0.14313452953366165
# Iteration 8, inertia 0.14283658148486386
# Converged at iteration 8: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.595881824766213
# Iteration 1, inertia 0.21768001983637936
# Iteration 2, inertia 0.16667859720700368
# Iteration 3, inertia 0.14633619706852813
# Iteration 4, inertia 0.1271039736602716
# Iteration 5, inertia 0.11897832441760553
# Iteration 6, inertia 0.11685256708545272
# Iteration 7, inertia 0.11615060804354135
# Iteration 8, inertia 0.11559852466114993
# Iteration 9, inertia 0.11542890676613823
# Iteration 10, inertia 0.11536799270465435
# Converged at iteration 10: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.43628475441958997
# Iteration 1, inertia 0.18770699438447294
# Iteration 2, inertia 0.14934615817148503
# Iteration 3, inertia 0.14474906005896607
# Iteration 4, inertia 0.14266548339899923
# Iteration 5, inertia 0.14034848424847307
# Iteration 6, inertia 0.13868218540454827
# Iteration 7, inertia 0.13816118623922857
# Iteration 8, inertia 0.138127797580313
# Converged at iteration 8: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.46495866597132063
# Iteration 1, inertia 0.1694893998219333
# Iteration 2, inertia 0.13998230433182288
# Iteration 3, inertia 0.12300476643785202
# Iteration 4, inertia 0.11586743010760403
# Iteration 5, inertia 0.11331468300515952
# Iteration 6, inertia 0.11265130557327928
# Iteration 7, inertia 0.11139018791709532
# Iteration 8, inertia 0.11108166997872777
# Converged at iteration 8: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.36664553850506365
# Iteration 1, inertia 0.15246813057349615
# Iteration 2, inertia 0.13263118176750077
# Iteration 3, inertia 0.12521874252091628
# Iteration 4, inertia 0.1218339074250502
# Iteration 5, inertia 0.12055464184558624
# Iteration 6, inertia 0.12033810906027054
# Converged at iteration 6: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.6056409181932613
# Iteration 1, inertia 0.23150635970515446
# Iteration 2, inertia 0.16276065150035887
# Iteration 3, inertia 0.14410290686007568
# Iteration 4, inertia 0.1377048305829354
# Iteration 5, inertia 0.130365887899057
# Iteration 6, inertia 0.12668409378216694
# Iteration 7, inertia 0.12639415321109085
# Iteration 8, inertia 0.1263379312366641
# Iteration 9, inertia 0.12623572425173926
# Converged at iteration 9: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.35475417765822237
# Iteration 1, inertia 0.1927624316849799
# Iteration 2, inertia 0.15963723565936563
# Iteration 3, inertia 0.1531020255964853
# Iteration 4, inertia 0.15192159838832775
# Iteration 5, inertia 0.151576496880265
# Converged at iteration 5: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.4870565739753411
# Iteration 1, inertia 0.20670894017710975
# Iteration 2, inertia 0.1580548113341917
# Iteration 3, inertia 0.14621312263095923
# Iteration 4, inertia 0.1400918840588235
# Iteration 5, inertia 0.13615463440861755
# Iteration 6, inertia 0.13278799529196
# Iteration 7, inertia 0.13234591480419244
# Iteration 8, inertia 0.13169970343737092
# Iteration 9, inertia 0.130855890666671
# Converged at iteration 9: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.44627748233221143
# Iteration 1, inertia 0.21034357614439975
# Iteration 2, inertia 0.16007293863938687
# Iteration 3, inertia 0.14373621718222093
# Iteration 4, inertia 0.14129694409852353
# Iteration 5, inertia 0.13533089015230518
# Iteration 6, inertia 0.13140905148201035
# Iteration 7, inertia 0.12543947113381274
# Iteration 8, inertia 0.12329158652349523
# Iteration 9, inertia 0.12311043662412427
# Converged at iteration 9: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.4206635805413478
# Iteration 1, inertia 0.1992795867511584
# Iteration 2, inertia 0.1476950758486921
# Iteration 3, inertia 0.13867292132390788
# Iteration 4, inertia 0.13587957499776865
# Iteration 5, inertia 0.1335745570887782
# Iteration 6, inertia 0.12908228146513445
# Iteration 7, inertia 0.12095378167797105
# Iteration 8, inertia 0.1165161364710191
# Iteration 9, inertia 0.11595984020737266
# Converged at iteration 9: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.42342981279810704
# Iteration 1, inertia 0.1828775590401748
# Iteration 2, inertia 0.14132377529966897
# Iteration 3, inertia 0.1240594321064228
# Iteration 4, inertia 0.1191528629410502
# Iteration 5, inertia 0.11721761145295717
# Iteration 6, inertia 0.11691935418977226
# Converged at iteration 6: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.31490590649297656
# Iteration 1, inertia 0.15879912556112902
# Iteration 2, inertia 0.131275830982711
# Iteration 3, inertia 0.12271055691844711
# Iteration 4, inertia 0.11841333508961456
# Iteration 5, inertia 0.1155567162808163
# Iteration 6, inertia 0.1143196702013175
# Iteration 7, inertia 0.11211687346003892
# Iteration 8, inertia 0.10958616157827553
# Converged at iteration 8: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.4435668806959681
# Iteration 1, inertia 0.22149726962199112
# Iteration 2, inertia 0.14727732089588433
# Iteration 3, inertia 0.12901341342211403
# Iteration 4, inertia 0.12523578331724858
# Iteration 5, inertia 0.12465736344913027
# Iteration 6, inertia 0.12414050398991772
# Iteration 7, inertia 0.12359771001870713
# Iteration 8, inertia 0.12327152999750646
# Iteration 9, inertia 0.12296555925948534
# Iteration 10, inertia 0.12267778265323569
# Iteration 11, inertia 0.12239535322748465
# Iteration 12, inertia 0.12225977968056902
# Converged at iteration 12: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.4839576467943108
# Iteration 1, inertia 0.188981695266713
# Iteration 2, inertia 0.14066026634257034
# Iteration 3, inertia 0.12667901745307222
# Iteration 4, inertia 0.1229423129215884
# Iteration 5, inertia 0.12032039137129245
# Iteration 6, inertia 0.11858148926884476
# Iteration 7, inertia 0.11800962628737784
# Iteration 8, inertia 0.11761187614683562
# Iteration 9, inertia 0.11751841050640043
# Converged at iteration 9: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.5320069140125165
# Iteration 1, inertia 0.21509422401819178
# Iteration 2, inertia 0.15710481761102832
# Iteration 3, inertia 0.13658976355022304
# Iteration 4, inertia 0.13439707327822806
# Iteration 5, inertia 0.13306566847878637
# Iteration 6, inertia 0.13255168853380359
# Iteration 7, inertia 0.1322434377572166
# Iteration 8, inertia 0.13220185338117388
# Converged at iteration 8: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.26376508583294095
# Iteration 1, inertia 0.16115579339698416
# Iteration 2, inertia 0.14129802915427978
# Iteration 3, inertia 0.13020703298342387
# Iteration 4, inertia 0.12257588851494232
# Iteration 5, inertia 0.12213543110005655
# Iteration 6, inertia 0.12195576081599391
# Iteration 7, inertia 0.12151903690728823
# Iteration 8, inertia 0.12123987212534415
# Converged at iteration 8: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.49845105258087485
# Iteration 1, inertia 0.17829038585387597
# Iteration 2, inertia 0.13612303774737616
# Iteration 3, inertia 0.12303709246552785
# Iteration 4, inertia 0.11776041005702842
# Iteration 5, inertia 0.11454671815083677
# Iteration 6, inertia 0.11344397180176898
# Iteration 7, inertia 0.1127463548597499
# Iteration 8, inertia 0.11128756126944339
# Iteration 9, inertia 0.1111681796149353
# Iteration 10, inertia 0.11106597263001051
# Converged at iteration 10: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.3981791737757594
# Iteration 1, inertia 0.18865972827632493
# Iteration 2, inertia 0.14620190466596075
# Iteration 3, inertia 0.1348174274830721
# Iteration 4, inertia 0.12501197813669887
# Iteration 5, inertia 0.12014218632814748
# Iteration 6, inertia 0.11548403203964135
# Iteration 7, inertia 0.11463146752749849
# Iteration 8, inertia 0.11375844704687448
# Converged at iteration 8: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.5778403987225902
# Iteration 1, inertia 0.18191582820452373
# Iteration 2, inertia 0.1365383431557172
# Iteration 3, inertia 0.12584986613784813
# Iteration 4, inertia 0.12151119928698365
# Iteration 5, inertia 0.11975934598500936
# Iteration 6, inertia 0.11887503037230633
# Iteration 7, inertia 0.11718420901158227
# Iteration 8, inertia 0.11703206862922434
# Converged at iteration 8: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.3353973579125777
# Iteration 1, inertia 0.19213118573340837
# Iteration 2, inertia 0.16595581743491292
# Iteration 3, inertia 0.1537955194342834
# Iteration 4, inertia 0.15080911630098306
# Iteration 5, inertia 0.14964017681745348
# Iteration 6, inertia 0.14849695636806257
# Iteration 7, inertia 0.14813268632688095
# Converged at iteration 7: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.43015372637581506
# Iteration 1, inertia 0.18729680943577784
# Iteration 2, inertia 0.13494847968287066
# Iteration 3, inertia 0.12903497095384492
# Iteration 4, inertia 0.1279533627033094
# Converged at iteration 4: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.5277000585273569
# Iteration 1, inertia 0.22937977643633226
# Iteration 2, inertia 0.19297501941684836
# Iteration 3, inertia 0.15848924849529067
# Iteration 4, inertia 0.143264695751054
# Iteration 5, inertia 0.14095887977151975
# Iteration 6, inertia 0.14062390630430405
# Iteration 7, inertia 0.1401482677823927
# Iteration 8, inertia 0.13913422998841235
# Iteration 9, inertia 0.13901173282129892
# Converged at iteration 9: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.3296978346955445
# Iteration 1, inertia 0.16308294940417567
# Iteration 2, inertia 0.13248040456591423
# Iteration 3, inertia 0.12701920875522862
# Iteration 4, inertia 0.12506900934423928
# Iteration 5, inertia 0.11924253027168999
# Iteration 6, inertia 0.11822741153007658
# Iteration 7, inertia 0.11793233970033348
# Converged at iteration 7: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.5232649434767032
# Iteration 1, inertia 0.18640415999638457
# Iteration 2, inertia 0.14182698070156974
# Iteration 3, inertia 0.12258588600512223
# Iteration 4, inertia 0.11903870955479312
# Iteration 5, inertia 0.11781713634599476
# Iteration 6, inertia 0.11765999125952505
# Converged at iteration 6: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.41561400709217716
# Iteration 1, inertia 0.18976098253916188
# Iteration 2, inertia 0.15773648327011425
# Iteration 3, inertia 0.14096831521407507
# Iteration 4, inertia 0.13318453153670545
# Iteration 5, inertia 0.13073035114883366
# Iteration 6, inertia 0.13044105512968562
# Iteration 7, inertia 0.13035551399431686
# Iteration 8, inertia 0.13028404594212806
# Converged at iteration 8: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.471173084846523
# Iteration 1, inertia 0.20453597246392966
# Iteration 2, inertia 0.15760923353794054
# Iteration 3, inertia 0.1478010094949099
# Iteration 4, inertia 0.14412980648602677
# Iteration 5, inertia 0.14317141041397072
# Iteration 6, inertia 0.1428969623164142
# Converged at iteration 6: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.3104242036292729
# Iteration 1, inertia 0.17865228499935024
# Iteration 2, inertia 0.15365120531841256
# Iteration 3, inertia 0.14759133913559047
# Iteration 4, inertia 0.14099824538423913
# Iteration 5, inertia 0.13431631318212445
# Iteration 6, inertia 0.13420327982892757
# Converged at iteration 6: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.39224499147174663
# Iteration 1, inertia 0.18123443541640685
# Iteration 2, inertia 0.15369935742430285
# Iteration 3, inertia 0.14350766010438673
# Iteration 4, inertia 0.13894804276049882
# Iteration 5, inertia 0.13335510673655818
# Iteration 6, inertia 0.13206563580040329
# Iteration 7, inertia 0.1319891587999318
# Iteration 8, inertia 0.1319575759151806
# Converged at iteration 8: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.37962093593695617
# Iteration 1, inertia 0.1720224826158342
# Iteration 2, inertia 0.1478771826386594
# Iteration 3, inertia 0.13742677955325489
# Iteration 4, inertia 0.1304327735956513
# Iteration 5, inertia 0.1301573190497088
# Converged at iteration 5: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.33990340546349934
# Iteration 1, inertia 0.17316842521926143
# Iteration 2, inertia 0.13678622459370385
# Iteration 3, inertia 0.12555125373170162
# Iteration 4, inertia 0.12268191710171893
# Iteration 5, inertia 0.12216711792250033
# Iteration 6, inertia 0.12167659657851672
# Iteration 7, inertia 0.12067507118595444
# Iteration 8, inertia 0.12043988005808193
# Iteration 9, inertia 0.11914938126281147
# Iteration 10, inertia 0.11898483525411499
# Converged at iteration 10: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.6362040943028386
# Iteration 1, inertia 0.2367629725158944
# Iteration 2, inertia 0.1561299055056451
# Iteration 3, inertia 0.13932522079094814
# Iteration 4, inertia 0.13306905585708703
# Iteration 5, inertia 0.12767950821259813
# Iteration 6, inertia 0.12225869568342844
# Iteration 7, inertia 0.12123643968608296
# Iteration 8, inertia 0.12065012339220503
# Converged at iteration 8: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.5251044047492341
# Iteration 1, inertia 0.23146308107156416
# Iteration 2, inertia 0.174938863935902
# Iteration 3, inertia 0.14609573016763275
# Iteration 4, inertia 0.13029851759463681
# Iteration 5, inertia 0.12571544786479058
# Iteration 6, inertia 0.12417669982957005
# Iteration 7, inertia 0.12197698923767517
# Converged at iteration 7: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.26613393394033646
# Iteration 1, inertia 0.1457070461174539
# Iteration 2, inertia 0.1291434479358176
# Iteration 3, inertia 0.12359220359523111
# Iteration 4, inertia 0.12290210753423648
# Iteration 5, inertia 0.1227109080887076
# Converged at iteration 5: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.4267403859006192
# Iteration 1, inertia 0.22085435565556796
# Iteration 2, inertia 0.17121327106476042
# Iteration 3, inertia 0.15936207920415874
# Iteration 4, inertia 0.15260737142339323
# Iteration 5, inertia 0.14904938270147355
# Iteration 6, inertia 0.14783932566911182
# Converged at iteration 6: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.37461996926197755
# Iteration 1, inertia 0.1755619002483742
# Iteration 2, inertia 0.14720251681458815
# Iteration 3, inertia 0.14153233911386848
# Iteration 4, inertia 0.1395416190655135
# Iteration 5, inertia 0.13855154609773185
# Iteration 6, inertia 0.13805438841303372
# Iteration 7, inertia 0.13796654669658595
# Converged at iteration 7: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.37696906722402057
# Iteration 1, inertia 0.18436910537296683
# Iteration 2, inertia 0.12960237591899942
# Iteration 3, inertia 0.12107715039589352
# Iteration 4, inertia 0.11930140502286113
# Iteration 5, inertia 0.1174689082695783
# Iteration 6, inertia 0.11694865132124733
# Iteration 7, inertia 0.11684937482446978
# Iteration 8, inertia 0.11676651631823036
# Iteration 9, inertia 0.11669525370355549
# Converged at iteration 9: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.41639547038887764
# Iteration 1, inertia 0.19934437768343868
# Iteration 2, inertia 0.15594346934919953
# Iteration 3, inertia 0.14520059886486367
# Iteration 4, inertia 0.14082511187228086
# Iteration 5, inertia 0.13868111300267633
# Iteration 6, inertia 0.1378279452125235
# Iteration 7, inertia 0.1376247194866365
# Converged at iteration 7: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.33029926059218057
# Iteration 1, inertia 0.18077698515542678
# Iteration 2, inertia 0.1404251178415959
# Iteration 3, inertia 0.1307107151179844
# Iteration 4, inertia 0.12594829411091896
# Iteration 5, inertia 0.12495692432037198
# Converged at iteration 5: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.40667408434517943
# Iteration 1, inertia 0.1868468672624107
# Iteration 2, inertia 0.1378687956899417
# Iteration 3, inertia 0.1327120833707555
# Iteration 4, inertia 0.13200289631916995
# Iteration 5, inertia 0.13121925002259097
# Iteration 6, inertia 0.12851650560314204
# Iteration 7, inertia 0.12748336008203542
# Iteration 8, inertia 0.12730392615872932
# Converged at iteration 8: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.39302083379829705
# Iteration 1, inertia 0.19893438328671514
# Iteration 2, inertia 0.15552475721837886
# Iteration 3, inertia 0.13123329637820366
# Iteration 4, inertia 0.12164138101469361
# Iteration 5, inertia 0.11636091127992586
# Iteration 6, inertia 0.11493899844651817
# Iteration 7, inertia 0.1147435274183351
# Converged at iteration 7: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.40174840754921204
# Iteration 1, inertia 0.15991719843920785
# Iteration 2, inertia 0.13907964060825562
# Iteration 3, inertia 0.13262432936843124
# Iteration 4, inertia 0.12515449905291948
# Iteration 5, inertia 0.11736438744034956
# Iteration 6, inertia 0.11691383177826321
# Iteration 7, inertia 0.11653470915038647
# Iteration 8, inertia 0.11626006430247558
# Converged at iteration 8: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.31389628853941354
# Iteration 1, inertia 0.174336156640342
# Iteration 2, inertia 0.12409413873748276
# Iteration 3, inertia 0.10797157337369234
# Iteration 4, inertia 0.10456579792432473
# Iteration 5, inertia 0.10413943980048788
# Converged at iteration 5: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.5010970013668232
# Iteration 1, inertia 0.18214325348245203
# Iteration 2, inertia 0.13690554900458585
# Iteration 3, inertia 0.12903793310418077
# Iteration 4, inertia 0.12656368049089786
# Iteration 5, inertia 0.12425588584973667
# Iteration 6, inertia 0.12360874602520464
# Converged at iteration 6: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.29444842725892284
# Iteration 1, inertia 0.1474861255486294
# Iteration 2, inertia 0.12764844511579493
# Iteration 3, inertia 0.1249069729249694
# Iteration 4, inertia 0.12327831882797048
# Iteration 5, inertia 0.1221559217833055
# Iteration 6, inertia 0.12098716565392363
# Iteration 7, inertia 0.1205110362100023
# Iteration 8, inertia 0.12003922137678137
# Iteration 9, inertia 0.11953070483805375
# Iteration 10, inertia 0.11933636871415099
# Iteration 11, inertia 0.1190960747751516
# Iteration 12, inertia 0.11900399782484755
# Converged at iteration 12: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.6090788920933761
# Iteration 1, inertia 0.18030912352328202
# Iteration 2, inertia 0.12662964583652067
# Iteration 3, inertia 0.11837377200169909
# Iteration 4, inertia 0.11822487843494031
# Converged at iteration 4: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.30449423060870323
# Iteration 1, inertia 0.16772827203097943
# Iteration 2, inertia 0.13758436546028235
# Iteration 3, inertia 0.13096866767035606
# Iteration 4, inertia 0.12839692297366642
# Iteration 5, inertia 0.12768661121547686
# Iteration 6, inertia 0.12707614988984245
# Converged at iteration 6: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.5462290598217155
# Iteration 1, inertia 0.2254783801185839
# Iteration 2, inertia 0.13820377370399614
# Iteration 3, inertia 0.12138276295516211
# Iteration 4, inertia 0.11892441273598557
# Iteration 5, inertia 0.11681905000819828
# Iteration 6, inertia 0.11289619475623888
# Iteration 7, inertia 0.10983078501083006
# Iteration 8, inertia 0.10898735103345603
# Iteration 9, inertia 0.10891036006190428
# Converged at iteration 9: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.32340165394505116
# Iteration 1, inertia 0.19706452351821171
# Iteration 2, inertia 0.1543309791569345
# Iteration 3, inertia 0.14131585746222589
# Iteration 4, inertia 0.1345134516025816
# Iteration 5, inertia 0.13265195366197302
# Iteration 6, inertia 0.13244384756385483
# Converged at iteration 6: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.4946227318055249
# Iteration 1, inertia 0.2518198095576819
# Iteration 2, inertia 0.21656428649858964
# Iteration 3, inertia 0.20717953709182874
# Iteration 4, inertia 0.1990007955841256
# Iteration 5, inertia 0.18122000914283198
# Iteration 6, inertia 0.15275420974212223
# Iteration 7, inertia 0.1487917936828221
# Iteration 8, inertia 0.14859727044149995
# Iteration 9, inertia 0.14833199581210355
# Iteration 10, inertia 0.1478810134422406
# Iteration 11, inertia 0.14716189601581497
# Iteration 12, inertia 0.14634378902211811
# Iteration 13, inertia 0.14431696517126438
# Iteration 14, inertia 0.14377365608234743
# Iteration 15, inertia 0.14258000633138965
# Iteration 16, inertia 0.14248269727527615
# Converged at iteration 16: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.2997731795784082
# Iteration 1, inertia 0.16040600388134302
# Iteration 2, inertia 0.14205663707681093
# Iteration 3, inertia 0.13532001652997297
# Iteration 4, inertia 0.13118681932207293
# Iteration 5, inertia 0.12406346673585134
# Iteration 6, inertia 0.12231173446529979
# Iteration 7, inertia 0.1220714325766714
# Converged at iteration 7: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.3274862697769153
# Iteration 1, inertia 0.16265889494315133
# Iteration 2, inertia 0.14006558886571957
# Iteration 3, inertia 0.1260583748134713
# Iteration 4, inertia 0.1218065105273701
# Iteration 5, inertia 0.11876424015535131
# Iteration 6, inertia 0.11707646509758911
# Iteration 7, inertia 0.11687022385689458
# Converged at iteration 7: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.4710214109774971
# Iteration 1, inertia 0.1818976131067552
# Iteration 2, inertia 0.12963739326361534
# Iteration 3, inertia 0.12134636013089307
# Iteration 4, inertia 0.11707806306075866
# Iteration 5, inertia 0.11493866019069446
# Iteration 6, inertia 0.11409693327216024
# Iteration 7, inertia 0.11343077377566282
# Converged at iteration 7: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.31260182741084
# Iteration 1, inertia 0.15823545270213263
# Iteration 2, inertia 0.13617472366779032
# Iteration 3, inertia 0.12532480242518573
# Iteration 4, inertia 0.12530340375369056
# Converged at iteration 4: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.31135045598530514
# Iteration 1, inertia 0.15909650832829508
# Iteration 2, inertia 0.14257548114850735
# Iteration 3, inertia 0.12411371934834424
# Iteration 4, inertia 0.12093781058870569
# Iteration 5, inertia 0.12072257289701965
# Iteration 6, inertia 0.12059781517831686
# Converged at iteration 6: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.4288962436075088
# Iteration 1, inertia 0.21950719335558808
# Iteration 2, inertia 0.1688933796652657
# Iteration 3, inertia 0.15009168962502112
# Iteration 4, inertia 0.14522639484184788
# Iteration 5, inertia 0.14192153844775388
# Iteration 6, inertia 0.13932273552376337
# Iteration 7, inertia 0.13873348291151466
# Iteration 8, inertia 0.13846752237946164
# Converged at iteration 8: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.43678258703709777
# Iteration 1, inertia 0.19109439306809775
# Iteration 2, inertia 0.1499262494926649
# Iteration 3, inertia 0.13438704739620988
# Iteration 4, inertia 0.12689935090527343
# Iteration 5, inertia 0.12441913378860513
# Iteration 6, inertia 0.12023701782014118
# Iteration 7, inertia 0.11789760019359398
# Iteration 8, inertia 0.11696740792857564
# Converged at iteration 8: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.4609910032459912
# Iteration 1, inertia 0.1746357700699092
# Iteration 2, inertia 0.13291227337684522
# Iteration 3, inertia 0.12621903725482275
# Iteration 4, inertia 0.11802813705802341
# Iteration 5, inertia 0.11404376549963223
# Converged at iteration 5: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.3057028650545438
# Iteration 1, inertia 0.14439652381945436
# Iteration 2, inertia 0.12274317542659761
# Iteration 3, inertia 0.12038888315982992
# Iteration 4, inertia 0.11749006418504782
# Iteration 5, inertia 0.11689750959337616
# Iteration 6, inertia 0.1161109951658445
# Iteration 7, inertia 0.11571445602774783
# Converged at iteration 7: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.3199042450261188
# Iteration 1, inertia 0.17495598002880258
# Iteration 2, inertia 0.13022466460220353
# Iteration 3, inertia 0.11952419649299062
# Iteration 4, inertia 0.10852679726451656
# Iteration 5, inertia 0.1045920216467923
# Iteration 6, inertia 0.10356630976434095
# Iteration 7, inertia 0.10331392411040895
# Iteration 8, inertia 0.1032462161930689
# Iteration 9, inertia 0.10315717783419404
# Iteration 10, inertia 0.102905471873167
# Iteration 11, inertia 0.10284230989993058
# Converged at iteration 11: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.5949056806082617
# Iteration 1, inertia 0.2062001257443982
# Iteration 2, inertia 0.15211410527229965
# Iteration 3, inertia 0.1364958088625059
# Iteration 4, inertia 0.1325857446851581
# Iteration 5, inertia 0.13130047662681485
# Iteration 6, inertia 0.13122457465740167
# Converged at iteration 6: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.3362656233397654
# Iteration 1, inertia 0.1614248447261608
# Iteration 2, inertia 0.13206846522062562
# Iteration 3, inertia 0.12425525506261835
# Iteration 4, inertia 0.12144516914377584
# Iteration 5, inertia 0.12042114329363586
# Iteration 6, inertia 0.11927894423937024
# Iteration 7, inertia 0.1184358573868931
# Iteration 8, inertia 0.11769930288678765
# Iteration 9, inertia 0.11748998637593858
# Iteration 10, inertia 0.11741456652403441
# Converged at iteration 10: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.3115666545845892
# Iteration 1, inertia 0.17526150321570158
# Iteration 2, inertia 0.1438789363304976
# Iteration 3, inertia 0.133315618597409
# Iteration 4, inertia 0.13263312009725084
# Converged at iteration 4: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.6076252790007515
# Iteration 1, inertia 0.24028835344437696
# Iteration 2, inertia 0.17001938060529206
# Iteration 3, inertia 0.15967049354219987
# Iteration 4, inertia 0.15499426432133692
# Iteration 5, inertia 0.1515190456727707
# Iteration 6, inertia 0.14828760068462962
# Iteration 7, inertia 0.1457523990212689
# Iteration 8, inertia 0.14478088580652862
# Iteration 9, inertia 0.14450093577728368
# Iteration 10, inertia 0.14435707699137443
# Converged at iteration 10: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.3058250945381195
# Iteration 1, inertia 0.1696888122929857
# Iteration 2, inertia 0.1521725832227601
# Iteration 3, inertia 0.14376933291790395
# Iteration 4, inertia 0.13934898153292857
# Iteration 5, inertia 0.13235860820110365
# Iteration 6, inertia 0.1308096134650751
# Iteration 7, inertia 0.12989642471501006
# Iteration 8, inertia 0.12686793076132916
# Iteration 9, inertia 0.12596888989266442
# Iteration 10, inertia 0.12584199865012707
# Converged at iteration 10: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.4933781751978588
# Iteration 1, inertia 0.17928857162805162
# Iteration 2, inertia 0.1512162880870875
# Iteration 3, inertia 0.1424119188784209
# Iteration 4, inertia 0.1389374788424519
# Iteration 5, inertia 0.1358127762262597
# Iteration 6, inertia 0.1354183125374691
# Converged at iteration 6: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.370457769802303
# Iteration 1, inertia 0.16596518355143064
# Iteration 2, inertia 0.14721256403742414
# Iteration 3, inertia 0.1401339160324902
# Iteration 4, inertia 0.13346148346417205
# Iteration 5, inertia 0.13119403362870205
# Iteration 6, inertia 0.12877008288343395
# Iteration 7, inertia 0.1280596330557913
# Iteration 8, inertia 0.12788930603659032
# Converged at iteration 8: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.4334847971524572
# Iteration 1, inertia 0.20724966403429945
# Iteration 2, inertia 0.17858330275212844
# Iteration 3, inertia 0.16326671389528816
# Iteration 4, inertia 0.15094519720453095
# Iteration 5, inertia 0.14724260754624902
# Iteration 6, inertia 0.1434253722871664
# Iteration 7, inertia 0.14182155645816652
# Iteration 8, inertia 0.14161949088592926
# Converged at iteration 8: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.3431462721220944
# Iteration 1, inertia 0.2142479805606255
# Iteration 2, inertia 0.18357677992340848
# Iteration 3, inertia 0.17141279238946378
# Iteration 4, inertia 0.14975770103235386
# Iteration 5, inertia 0.13419162892245626
# Iteration 6, inertia 0.13152080869040508
# Iteration 7, inertia 0.1284776356063179
# Iteration 8, inertia 0.12755804078252547
# Iteration 9, inertia 0.1264933741248418
# Iteration 10, inertia 0.12584315975978963
# Converged at iteration 10: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.3769353269263722
# Iteration 1, inertia 0.18571094165241098
# Iteration 2, inertia 0.1478526186957873
# Iteration 3, inertia 0.12983567936533003
# Iteration 4, inertia 0.12877871358797718
# Converged at iteration 4: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.32501114874372544
# Iteration 1, inertia 0.1663041565047386
# Iteration 2, inertia 0.1577640840644433
# Iteration 3, inertia 0.15053667160699544
# Iteration 4, inertia 0.13834515213788423
# Iteration 5, inertia 0.13379311176859596
# Iteration 6, inertia 0.13256071193425437
# Iteration 7, inertia 0.132254409714744
# Iteration 8, inertia 0.13204679898162314
# Iteration 9, inertia 0.13194987015003498
# Converged at iteration 9: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.4300758767374445
# Iteration 1, inertia 0.19226575115964697
# Iteration 2, inertia 0.13227915566264298
# Iteration 3, inertia 0.11931559627472497
# Iteration 4, inertia 0.1145879387842181
# Iteration 5, inertia 0.11119388458674251
# Iteration 6, inertia 0.1105192091509897
# Iteration 7, inertia 0.11042827051239928
# Converged at iteration 7: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.5572617550794661
# Iteration 1, inertia 0.2647595412719663
# Iteration 2, inertia 0.1637313536410521
# Iteration 3, inertia 0.13201166572008333
# Iteration 4, inertia 0.12991612125583038
# Iteration 5, inertia 0.1293647652338082
# Iteration 6, inertia 0.12929535259207536
# Converged at iteration 6: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.33800741883428403
# Iteration 1, inertia 0.16701367244991205
# Iteration 2, inertia 0.14824467723392082
# Iteration 3, inertia 0.1397689441341388
# Iteration 4, inertia 0.1367802517864934
# Iteration 5, inertia 0.1359659078713923
# Iteration 6, inertia 0.13576587522062292
# Converged at iteration 6: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.5224211383658502
# Iteration 1, inertia 0.1861884333437313
# Iteration 2, inertia 0.15274692022670225
# Iteration 3, inertia 0.14764779859803998
# Iteration 4, inertia 0.14339187127730568
# Iteration 5, inertia 0.14233510072992164
# Iteration 6, inertia 0.14200956280853577
# Iteration 7, inertia 0.14162618919743045
# Iteration 8, inertia 0.14068750457653642
# Converged at iteration 8: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.5761605395715697
# Iteration 1, inertia 0.19296467083992624
# Iteration 2, inertia 0.1611883244150281
# Iteration 3, inertia 0.15555447537529302
# Iteration 4, inertia 0.15455780524454985
# Converged at iteration 4: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.4685861252062153
# Iteration 1, inertia 0.2418750763619293
# Iteration 2, inertia 0.18362085261128464
# Iteration 3, inertia 0.16084581570519146
# Iteration 4, inertia 0.15580948509538217
# Iteration 5, inertia 0.15425047066316686
# Iteration 6, inertia 0.15405818447798486
# Converged at iteration 6: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.2668479300369961
# Iteration 1, inertia 0.13912856666055443
# Iteration 2, inertia 0.12664693574012093
# Iteration 3, inertia 0.12392646947592485
# Iteration 4, inertia 0.12229458289660823
# Iteration 5, inertia 0.12190506119210998
# Iteration 6, inertia 0.12172509672205639
# Converged at iteration 6: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.43789038332158836
# Iteration 1, inertia 0.1896148129202481
# Iteration 2, inertia 0.13523613794857295
# Iteration 3, inertia 0.12178138608115044
# Iteration 4, inertia 0.11934324574556936
# Iteration 5, inertia 0.11884748509251772
# Iteration 6, inertia 0.11866074435112425
# Iteration 7, inertia 0.11784881682618863
# Iteration 8, inertia 0.11755530474326101
# Converged at iteration 8: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.3481199333105194
# Iteration 1, inertia 0.17415411729733382
# Iteration 2, inertia 0.1376344019599457
# Iteration 3, inertia 0.12876460975422355
# Iteration 4, inertia 0.12580725562290931
# Iteration 5, inertia 0.12427668397815175
# Iteration 6, inertia 0.12330478705809254
# Iteration 7, inertia 0.12283473144457122
# Iteration 8, inertia 0.12214289533353255
# Iteration 9, inertia 0.12144941431268866
# Iteration 10, inertia 0.12081036496144605
# Iteration 11, inertia 0.12028541714260692
# Iteration 12, inertia 0.11992914180925952
# Converged at iteration 12: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.32720455155885636
# Iteration 1, inertia 0.1866675478706669
# Iteration 2, inertia 0.13793726547224439
# Iteration 3, inertia 0.13075468356443978
# Iteration 4, inertia 0.13001419391035826
# Iteration 5, inertia 0.12930540846473065
# Iteration 6, inertia 0.1288375173246423
# Iteration 7, inertia 0.12861542120492792
# Iteration 8, inertia 0.12805675986678877
# Iteration 9, inertia 0.12741616528526042
# Converged at iteration 9: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.6926040377627994
# Iteration 1, inertia 0.20751012922951387
# Iteration 2, inertia 0.16095934728565459
# Iteration 3, inertia 0.15032324112168874
# Iteration 4, inertia 0.14685938713157157
# Iteration 5, inertia 0.14234992125866097
# Iteration 6, inertia 0.1377045679344226
# Iteration 7, inertia 0.13544191707830283
# Iteration 8, inertia 0.13365330496493383
# Iteration 9, inertia 0.13208433406324765
# Iteration 10, inertia 0.13113895998716654
# Iteration 11, inertia 0.1309416715469432
# Converged at iteration 11: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.38808810743930855
# Iteration 1, inertia 0.17778497595460757
# Iteration 2, inertia 0.15406904511482886
# Iteration 3, inertia 0.14053274766456605
# Iteration 4, inertia 0.13185496802258564
# Iteration 5, inertia 0.12769175494289237
# Iteration 6, inertia 0.12722221488240623
# Iteration 7, inertia 0.12651836523413593
# Iteration 8, inertia 0.1259214786624396
# Converged at iteration 8: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.3131758883261179
# Iteration 1, inertia 0.16696287863111503
# Iteration 2, inertia 0.14858202604500118
# Iteration 3, inertia 0.14131654557704543
# Iteration 4, inertia 0.13835141364418507
# Iteration 5, inertia 0.13749395045881727
# Iteration 6, inertia 0.13736688972037747
# Converged at iteration 6: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.3460839687733962
# Iteration 1, inertia 0.14476888626608095
# Iteration 2, inertia 0.1219893639763031
# Iteration 3, inertia 0.11820808482508334
# Iteration 4, inertia 0.11741055294280853
# Iteration 5, inertia 0.11708056667859452
# Iteration 6, inertia 0.11654704094757419
# Iteration 7, inertia 0.11590775886165211
# Iteration 8, inertia 0.11528629758877741
# Iteration 9, inertia 0.11462059685582764
# Iteration 10, inertia 0.11454604766393064
# Iteration 11, inertia 0.11447195466985728
# Iteration 12, inertia 0.11436083173381525
# Iteration 13, inertia 0.11424747396102557
# Converged at iteration 13: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.5793606389095471
# Iteration 1, inertia 0.18428559919652845
# Iteration 2, inertia 0.15499932666455443
# Iteration 3, inertia 0.14835860177523819
# Iteration 4, inertia 0.14562965461318317
# Iteration 5, inertia 0.14437712852801474
# Iteration 6, inertia 0.14315069069078074
# Iteration 7, inertia 0.14179428012685016
# Iteration 8, inertia 0.13068949979441194
# Iteration 9, inertia 0.11607128714628588
# Iteration 10, inertia 0.11563808357760194
# Converged at iteration 10: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.2751066651367127
# Iteration 1, inertia 0.15810584937199626
# Iteration 2, inertia 0.14249170462391303
# Iteration 3, inertia 0.13611034408493836
# Iteration 4, inertia 0.1294121297147239
# Iteration 5, inertia 0.12598396277286547
# Iteration 6, inertia 0.12414567507309862
# Iteration 7, inertia 0.12333829473016657
# Iteration 8, inertia 0.12256551533316186
# Iteration 9, inertia 0.12213441694614789
# Iteration 10, inertia 0.12191090238318246
# Converged at iteration 10: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.440333877117896
# Iteration 1, inertia 0.22424306592059348
# Iteration 2, inertia 0.1756431117691591
# Iteration 3, inertia 0.14899067479394396
# Iteration 4, inertia 0.13713056207862598
# Iteration 5, inertia 0.1333345338964666
# Iteration 6, inertia 0.13047686636023384
# Iteration 7, inertia 0.12753813151165044
# Iteration 8, inertia 0.1260894295205474
# Iteration 9, inertia 0.12560069294391135
# Iteration 10, inertia 0.1251400138168085
# Iteration 11, inertia 0.12460778662847467
# Iteration 12, inertia 0.12443831763134583
# Converged at iteration 12: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.2933002742594156
# Iteration 1, inertia 0.16403994198807229
# Iteration 2, inertia 0.1291003317057484
# Iteration 3, inertia 0.11668202446528642
# Iteration 4, inertia 0.11165010152853004
# Iteration 5, inertia 0.10946147909412514
# Iteration 6, inertia 0.10907942523607256
# Converged at iteration 6: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.3764877186224605
# Iteration 1, inertia 0.20279553824587107
# Iteration 2, inertia 0.16306915593031662
# Iteration 3, inertia 0.14995131025572556
# Iteration 4, inertia 0.1474918862375956
# Iteration 5, inertia 0.14567472229458622
# Iteration 6, inertia 0.13303720186576237
# Iteration 7, inertia 0.11990122495469584
# Iteration 8, inertia 0.11668959289011901
# Iteration 9, inertia 0.11619140264904942
# Converged at iteration 9: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.40229332423179986
# Iteration 1, inertia 0.2071618452257489
# Iteration 2, inertia 0.16885946799847223
# Iteration 3, inertia 0.1517207067540254
# Iteration 4, inertia 0.14838779288244738
# Iteration 5, inertia 0.1471845431051791
# Iteration 6, inertia 0.14346458272727497
# Iteration 7, inertia 0.14070511328856278
# Iteration 8, inertia 0.13912561418500213
# Iteration 9, inertia 0.13874833335997352
# Iteration 10, inertia 0.13802850395535968
# Iteration 11, inertia 0.1375745269393001
# Converged at iteration 11: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.3801585237622456
# Iteration 1, inertia 0.19374914818935474
# Iteration 2, inertia 0.1688454034573977
# Iteration 3, inertia 0.1562062575046415
# Iteration 4, inertia 0.14927036858232093
# Iteration 5, inertia 0.14502067658988652
# Iteration 6, inertia 0.14069534883424378
# Iteration 7, inertia 0.14004010591128316
# Iteration 8, inertia 0.13938205850701613
# Iteration 9, inertia 0.1389764156151543
# Iteration 10, inertia 0.13862456751236105
# Iteration 11, inertia 0.13800028402382616
# Iteration 12, inertia 0.13643260994262824
# Iteration 13, inertia 0.1361911359172461
# Iteration 14, inertia 0.13605840244090447
# Converged at iteration 14: center shift 0.0 within tolerance 1.1735382298696006e-06
# KMeans(init='random', max_iter=100, n_clusters=50, n_init=100, verbose=1)

# %%
km2.labels_
# Out:
# array([29, 21, 48, 31,  0, 10, 21,  4, 49, 13, 47, 35, 21, 40,  7, 16, 21,
#        15, 35, 13, 21,  0, 21, 29, 21, 21, 21, 21,  5, 35, 47, 39, 13,  1,
#        31, 46, 46, 32, 32, 32, 46, 13, 38, 18, 17, 40, 42, 33, 40, 46, 46,
#        38, 35,  0,  9, 13,  5, 37, 35, 16,  1, 40, 48, 44, 15, 38, 15, 47,
#        37, 49, 15, 47, 15, 20, 39, 16, 24, 35, 47, 47, 47, 46, 15, 35,  8,
#        36, 15,  4, 25,  2, 11, 24,  1, 37,  4, 26,  5, 33, 22, 26, 15, 22,
#         5, 25, 24, 34, 25, 44,  3,  3, 36, 25,  3,  3, 25,  5, 11, 34, 11,
#        46, 15,  9, 16, 41,  3,  8, 44, 46,  3,  2, 38, 46, 49, 38,  7,  4,
#        26, 17, 36, 35, 11, 44,  2, 11,  5, 24, 25, 16,  1, 11,  7,  5, 36,
#        26, 12, 25, 49, 26, 24, 28, 40, 46, 35,  1, 23, 36, 40, 40, 44, 18,
#        19, 38, 23, 15, 14, 25,  5,  1, 13, 37, 25,  6, 33,  4,  7,  1,  9,
#        38, 25, 41,  1, 35, 22,  3, 25, 36, 36, 38, 37, 14, 32, 25, 17, 25,
#         3, 22, 36, 37, 38,  2, 18, 38,  5, 31,  3, 25, 23, 23, 36, 38, 18,
#        33, 13, 13, 38, 22,  0,  6, 31,  6, 15,  5, 25, 44, 23, 15, 23, 33,
#        16, 37, 32, 25, 37, 30, 37, 25, 26,  6, 32, 33, 18, 25,  3, 33, 14,
#        41, 16, 26, 41, 32, 25,  4, 25,  1, 49, 15, 16,  9, 38,  7, 25, 49,
#        45, 12, 46, 34, 28, 40, 15,  3, 32, 11, 25, 40,  4, 33, 34, 46, 37,
#        30, 25, 24, 32, 33, 25,  3, 49,  5, 18, 27, 16,  6, 31, 13, 25, 16,
#        25, 17, 44,  0, 31,  9, 13, 35, 32,  2,  1,  7, 37,  9, 42, 45, 34,
#        39,  1, 31, 49, 12, 48, 26, 39, 43, 44, 36, 17, 39, 45, 33, 12, 20,
#         1, 19, 42, 43, 28, 26, 28, 49, 45, 42, 19,  1, 45, 12, 19, 39,  5,
#         9, 34, 29, 43, 28, 29,  9, 42, 28, 31, 21, 37,  1, 19,  1,  2, 45,
#        49, 21,  1, 44, 48, 19, 28, 35, 27, 48, 38, 45, 20,  8, 19, 12,  4,
#         1, 12,  1, 43, 42, 45, 21, 19, 11, 38, 17, 48, 22,  7, 29, 20,  7,
#        29, 48, 12, 45, 16, 49, 40,  8,  9,  3, 34, 14,  2, 18, 25,  8, 38,
#         8, 18,  0, 14,  9, 25,  7, 27, 27, 27, 32, 31, 38, 40, 25, 36, 24,
#        17, 23, 12, 28, 23,  8, 17, 11, 18, 18, 18], dtype=int32)

# %%
df_clean2['class'] = km2.labels_
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_clean2
# Out:
#       global_id                    MainFunctional  \
# 0     272726711  Многоэтажный многоквартирный дом
# 1     272726777  Многоэтажный многоквартирный дом
# 2     272726846  Многоэтажный многоквартирный дом
# 3     272726887  Многоэтажный многоквартирный дом
# 4     272726890  Многоэтажный многоквартирный дом
# ..          ...                               ...
# 448  1035998832  Многоэтажный многоквартирный дом
# 449  1037160508  Многоэтажный многоквартирный дом
# 450  1037862689  Многоэтажный многоквартирный дом
# 451  1037862798  Многоэтажный многоквартирный дом
# 452  1037862817  Многоэтажный многоквартирный дом
#
#                                 AdmArea              lng              lat  \
# 0    [Восточный административный округ]  37.795564262836  55.761349247059
# 1        [Южный административный округ]  37.662497752668  55.606339142276
# 2        [Южный административный округ]  37.677879903019  55.642152231422
# 3     [Северный административный округ]  37.500611345616  55.801860524702
# 4     [Северный административный округ]  37.561879230614  55.879979804897
# ..                                  ...              ...              ...
# 448      [Южный административный округ]  37.609481885433  55.673467591528
# 449   [Северный административный округ]  37.539289973813  55.840327725186
# 450   [Северный административный округ]  37.474834237220  55.859468813591
# 451   [Северный административный округ]  37.474834237220  55.859468813591
# 452   [Северный административный округ]  37.474834237220  55.859468813591
#
#      class
# 0       29
# 1       21
# 2       48
# 3       31
# 4        0
# ..     ...
# 448     17
# 449     11
# 450     18
# 451     18
# 452     18
#
# [453 rows x 6 columns]

# %%
km2.inertia_
# Out:
# 0.10284230989993058

# %% [markdown]
# ## Plot found clusters on a map

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, cluster in zip(df_clean2['lat'], df_clean2['lng'], df_clean2['class']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
# add markers to map
for i, lat, lng, name in zip(venues.index, venues['lat'], venues['lng'], venues['name']):
    label = '{}: {}'.format(i, name.split("(")[0])
    
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_clusters)             
        
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#km2.cluster_centers_
metro2.drop(['NumOfProp','Distance'], axis=1)

# %%
# Find the closest metro station to the found cluster centroid
from scipy.spatial import distance

s1 = km2.cluster_centers_
s2 = metro2.loc[:,['lat','lng']].values
print(distance.cdist(s1,s2).min(axis=1))
s2

# %%
num = []
dist = []
for st in metro2.index:
    count = 0
    loc_dist = []
    for prop in df_clean2.index: #['class']:
        if st == df_clean2.loc[prop, 'class']:
            count+=1
            #print("{}:{}".format(metro.iloc[st,'lat'], df_clean.loc[st,'lat']))
            #print("{} {} {} {}".format(metro.loc[st,'lng'], metro.loc[st,'lat'], df_clean.loc[prop,'lng'], df_clean.loc[prop,'lat']))
            #loc_dist.append(haversine(metro.loc[st,'lng'], metro.loc[st,'lat'], df_clean.loc[st,'lng'], df_clean.loc[st,'lat']))
            #metro.loc[st,'lat']-df_clean.loc[st,'lat'])
            mtr = [metro2.loc[st,'lat'], metro2.loc[st,'lng']]
            pty = [df_clean2.loc[prop,'lat'], df_clean2.loc[prop,'lng']]
            mtr_rad = [radians(_) for _ in mtr]
            pty_rad = [radians(_) for _ in pty]
            result = haversine_distances([mtr_rad, pty_rad])[0,1]
            loc_dist.append(result*6371000/1000)
    
    num.append(count)
    dist.append(loc_dist)
#print(num)
#print(dist)
metro2['NumOfProp'] = num
metro2['Distance'] = dist
