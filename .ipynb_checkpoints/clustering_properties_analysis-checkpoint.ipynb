# %% [markdown]
# # Clustering new real estate properties around metro stations
#
# This analysis is focused on the real estate properties currently being under construction by clustering them around metro stations to reveal perspective areas. Since the real estate properties development is growing faster than the city infrastructure the analysis can be useful for real estate marketing.

# %% [markdown]
# ## Import necessary packages

# %%
#!pip3 install seaborn
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import requests
import urllib.request
import csv
import json
from pandas.io.json import json_normalize

# %% [markdown]
# ## Install geopy and obtain coordinates of the city center

# %%
#!pip3 install geopy
from geopy.geocoders import Nominatim
import folium 

address = 'Moscow, RUS'

geolocator = Nominatim(user_agent="my-app")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of city are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of city are 55.7504461, 37.6174943.

# %% [markdown]
# ## Specify Foursquare credentials

# %%
# @hidden_cell
CLIENT_ID = 'ACZJOECQKRZ2W0XWIZRIOUW4YGI3030QJWHVTMVZZKLH0AMN' # your Foursquare ID
CLIENT_SECRET = 'E50W0Y52T0RTMTAQDUSMW02AFR5YANAIQIUKEY2PAGY4XP4K' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %% [markdown]
# ## Retrieve metro station category venues as a JSON file

# %%
radius = 15000
n_results = 500

# Metro stations
cat_id = '4bf58dd8d48988d1fd931735'

# beer house
url = 'https://api.foursquare.com/v2/venues/search?&categoryId={}&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
#url = 'https://api.foursquare.com/v2/venues/search?&categoryId=4bf58dd8d48988d137941735&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    #url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    cat_id,
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    n_results)
print(url)
# Out:
# https://api.foursquare.com/v2/venues/search?&categoryId=4bf58dd8d48988d1fd931735&client_id=ACZJOECQKRZ2W0XWIZRIOUW4YGI3030QJWHVTMVZZKLH0AMN&client_secret=E50W0Y52T0RTMTAQDUSMW02AFR5YANAIQIUKEY2PAGY4XP4K&v=20180605&ll=55.7504461,37.6174943&radius=15000&limit=500

# %%
results = requests.get(url).json()

# %% [markdown]
# ## Normalize JSON and check shape and indices

# %%
results['response']['venues']
venues = json_normalize(results['response']['venues'])
type(venues)
venues.shape
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
# (50, 18)

# %%
print(venues.columns)
filtered_columns = ['name', 'location.lat', 'location.lng']
venues = venues.loc[:, filtered_columns]
# Out:
# Index(['id', 'name', 'categories', 'referralId', 'hasPerk', 'location.address',
#        'location.crossStreet', 'location.lat', 'location.lng',
#        'location.labeledLatLngs', 'location.distance', 'location.postalCode',
#        'location.cc', 'location.neighborhood', 'location.city',
#        'location.state', 'location.country', 'location.formattedAddress'],
#       dtype='object')

# %%
# clean columns
venues.columns = [col.split(".")[-1] for col in venues.columns]

venues.shape
# Out:
# (50, 3)

# %%
venues.head(10)
# Out:
#                                                 name        lat        lng
# 0              metro Kitay-gorod (Метро Китай-город)  55.755196  37.633110
# 1  metro Taganskaya, line 5 (Метро Таганская, кол...  55.742171  37.653771
# 2                     metro Rimskaya (Метро Римская)  55.746339  37.681594
# 3  metro Komsomolskaya, line 5 (Метро Комсомольск...  55.775596  37.654834
# 4              metro Park Pobedy (Метро Парк Победы)  55.737146  37.515340
# 5      metro Tsvetnoy Bulvar (Метро Цветной бульвар)  55.771525  37.620784
# 6  metro Kiyevskaya, line 5 (Метро Киевская, коль...  55.743576  37.566194
# 7        metro Krasnye Vorota (Метро Красные ворота)  55.768659  37.649220
# 8                 metro Sokolniki (Метро Сокольники)  55.789241  37.680353
# 9  metro Belorusskaya, line 5 (Метро Белорусская,...  55.775309  37.582662

# %% [markdown]
# ## Create a map with the obtained metro stations

# %%
# create map of New York using latitude and longitude values
map = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for i, lat, lng, name in zip(venues.index, venues['lat'], venues['lng'], venues['name']):
    label = '{}: {}'.format(i, name.split('(')[0])
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map)  
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Find and preprocess a list of houses under construction
#
# ### We have to specify Windows-1251 encoding in order to properly read JSON values

# %%
flats = pd.read_json('data-24713-2020-06-04.json', encoding = "Windows-1251") #"ISO-8859-1")
flats.shape
# Out:
# (1579, 25)

# %%
flats.head()
filtered_columns = ['global_id', 'Coordinates', 'MainFunctional', 'AdmArea']
flats = flats.loc[:, filtered_columns]

# %%
df_clean = flats

# %%
df_clean = df_clean[df_clean.apply(lambda row: row.astype(str).str.contains('Зеленоград').any() == False, axis=1)]
df_clean
# Out:
#        global_id                      Coordinates  \
# 0      272715485  37.693324502046,55.797677127859
# 1      272715489  37.489798795354,55.626083209178
# 2      272715492  37.569607151073,55.685225196907
# 3      272715504  37.741970758303,55.690432838423
# 4      272715510  37.595682531523,55.771000504538
# ...          ...                              ...
# 1574  1037819557  37.884342235382,55.724229565696
# 1575  1037819558  37.699581107495,55.697021718182
# 1576  1037862689  37.474834237220,55.859468813591
# 1577  1037862798  37.474834237220,55.859468813591
# 1578  1037862817  37.474834237220,55.859468813591
#
#                                          MainFunctional  \
# 0                                     Подземная стоянка
# 1                                                  Храм
# 2                                        Офисное здание
# 3     Объект аварийно-спасательной службы, формирования
# 4                                             Гостиница
# ...                                                 ...
# 1574                         Объект торговли иного типа
# 1575                                           Больница
# 1576                   Многоэтажный многоквартирный дом
# 1577                   Многоэтажный многоквартирный дом
# 1578                   Многоэтажный многоквартирный дом
#
#                                                 AdmArea
# 0                    [Восточный административный округ]
# 1                 [Юго-Западный административный округ]
# 2                 [Юго-Западный административный округ]
# 3                [Юго-Восточный административный округ]
# 4                  [Центральный административный округ]
# ...                                                 ...
# 1574          [Северо-Восточный административный округ]
# 1575  [Северный административный округ, Юго-Восточны...
# 1576                  [Северный административный округ]
# 1577                  [Северный административный округ]
# 1578                  [Северный административный округ]
#
# [1541 rows x 4 columns]

# %% [markdown]
# ## Select residential developing facilities only

# %%
df_clean = df_clean[df_clean.apply(lambda row: row.astype(str).str.contains('Многоэтажный многоквартирный дом').any(), axis=1)]
df_clean.reset_index(drop=True, inplace=True)

# %%
df_clean
# Out:
#       global_id                      Coordinates  \
# 0     272726711  37.795564262836,55.761349247059
# 1     272726777  37.662497752668,55.606339142276
# 2     272726846  37.677879903019,55.642152231422
# 3     272726887  37.500611345616,55.801860524702
# 4     272726890  37.561879230614,55.879979804897
# ..          ...                              ...
# 448  1035998832  37.609481885433,55.673467591528
# 449  1037160508  37.539289973813,55.840327725186
# 450  1037862689  37.474834237220,55.859468813591
# 451  1037862798  37.474834237220,55.859468813591
# 452  1037862817  37.474834237220,55.859468813591
#
#                        MainFunctional                             AdmArea
# 0    Многоэтажный многоквартирный дом  [Восточный административный округ]
# 1    Многоэтажный многоквартирный дом      [Южный административный округ]
# 2    Многоэтажный многоквартирный дом      [Южный административный округ]
# 3    Многоэтажный многоквартирный дом   [Северный административный округ]
# 4    Многоэтажный многоквартирный дом   [Северный административный округ]
# ..                                ...                                 ...
# 448  Многоэтажный многоквартирный дом      [Южный административный округ]
# 449  Многоэтажный многоквартирный дом   [Северный административный округ]
# 450  Многоэтажный многоквартирный дом   [Северный административный округ]
# 451  Многоэтажный многоквартирный дом   [Северный административный округ]
# 452  Многоэтажный многоквартирный дом   [Северный административный округ]
#
# [453 rows x 4 columns]

# %% [markdown]
# ## Perform some data cleaning and manipulations

# %%
#df_clean[['lat','lng']] = pd.DataFrame(df_clean['Coordinates'].astype(str).str.split(expand=True), index = df_clean.index)


df_clean[['lng','lat']] = df_clean['Coordinates'].astype(str).str.split(",", expand=True)
df_clean.drop(['Coordinates'], axis=1, inplace=True)
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_clean2 = df_clean

# %% [markdown]
# ## Create a map of developing buildings

# %%
# create map of New York using latitude and longitude values
map = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, gid in zip(df_clean['lat'], df_clean['lng'], df_clean['global_id']):
    label = '{}'.format(name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map)  
    
    
# add markers to map
# for lat, lng, name in zip(venues['lat'], venues['lng'], venues['name']):
#     label = '{}'.format(name)
#     label = folium.Popup(label, parse_html=True)
#     folium.CircleMarker(
#         [lat, lng],
#         radius=5,
#         popup=label,
#         color='blue',
#         fill=True,
#         fill_color='#3186cc',
#         fill_opacity=0.7,
#         parse_html=False).add_to(map)      
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Create an array of initial centers

# %%
centers = np.array(venues[['lat','lng']])
centers.shape
# Out:
# (50, 2)

# %% [markdown]
# ## Perform a clusterization with pre-fixed initial centers

# %%
from sklearn.cluster import KMeans
kclusters = 50
km = KMeans(n_clusters=kclusters, init=centers, max_iter=100, n_init=1, verbose=1)
km.fit(df_clean[['lat','lng']])
# Out:
# Initialization complete
# Iteration 0, inertia 0.5927100713536174
# Iteration 1, inertia 0.20571571474782216
# Iteration 2, inertia 0.1639615562872975
# Iteration 3, inertia 0.1494543039738734
# Iteration 4, inertia 0.137753597979588
# Iteration 5, inertia 0.13403567260595678
# Iteration 6, inertia 0.13264023664364172
# Iteration 7, inertia 0.131717375057557
# Iteration 8, inertia 0.13086127411062912
# Iteration 9, inertia 0.1303146818186013
# Iteration 10, inertia 0.13018813748053681
# Iteration 11, inertia 0.1300847208997707
# Iteration 12, inertia 0.1299586826490822
# Iteration 13, inertia 0.12971115613942505
# Iteration 14, inertia 0.12960449689522138
# Converged at iteration 14: center shift 0.0 within tolerance 1.1735382298696006e-06
# KMeans(init=array([[55.755196  , 37.63311   ],
#        [55.7421714 , 37.6537708 ],
#        [55.74633873, 37.68159376],
#        [55.775596  , 37.654834  ],
#        [55.73714575, 37.5153401 ],
#        [55.77152462, 37.62078425],
#        [55.74357583, 37.56619443],
#        [55.768659  , 37.64922   ],
#        [55.78924086, 37.68035333],
#        [55.77530925, 37.58266216],
#        [55.73169041, 37.66491138],
#        [55.74717935, 37.68164804],
#        [55.77712194, 37.58249817],
#        [55.731724...
#        [55.6329867 , 37.51899719],
#        [55.65893   , 37.74961   ],
#        [55.86064619, 37.4363637 ],
#        [55.62011559, 37.66949824],
#        [55.74476706, 37.86477063],
#        [55.68773406, 37.57354259],
#        [55.70626394, 37.77176077],
#        [55.7778624 , 37.52102682],
#        [55.78842224, 37.75067568],
#        [55.75259792, 37.41253903],
#        [55.87731269, 37.48229586],
#        [55.86661   , 37.54714   ],
#        [55.82223583, 37.64139043]]),
#        max_iter=100, n_clusters=50, n_init=1, verbose=1)

# %%
km.labels_
# Out:
# array([17, 40, 40, 19, 48, 46, 40, 14, 34,  6, 28, 31, 40,  5, 26, 11, 40,
#        49, 31,  0, 40, 48, 40, 17, 40, 40, 40, 40, 10, 31, 32, 42,  6, 43,
#        20, 44, 44, 39, 39, 39, 44,  6,  0, 47, 35, 36, 28, 30, 24, 44, 44,
#         1, 31, 36, 44,  6,  2, 32, 31, 11, 43, 12, 40, 37,  5,  0, 49, 28,
#        32, 34,  5, 28,  5, 47, 42, 11,  8, 31, 28, 28, 28, 44, 49, 31, 13,
#        45, 49, 49, 38, 33, 48,  8, 43, 32, 14, 14,  1, 22, 29, 14, 49, 29,
#        10, 38, 11, 48, 38, 37, 25, 25, 45, 38, 25, 25, 38, 10, 48, 16, 48,
#        44, 49, 34, 11, 46, 25, 13, 37, 30, 25, 33,  0,  4, 34, 10, 26, 14,
#        14, 35, 45, 32, 48, 37, 33, 48, 10,  8, 38, 11, 43, 48, 26,  2, 45,
#        14, 19, 38, 34, 14,  8, 38, 12, 44, 32, 43, 41, 15, 36, 24, 37, 47,
#        18, 10, 41, 49, 33, 38, 10, 43,  0, 32, 38, 38, 22, 14, 26, 43, 34,
#        10, 38, 46, 43, 32, 29, 25, 38, 15, 15, 10, 32, 33, 39, 38, 35, 38,
#        25, 23, 15, 32,  0, 33, 47,  1, 21, 19, 25, 38, 41, 41, 15, 10, 47,
#         9,  6,  6, 10, 23, 14, 38, 19, 38, 49, 10, 38, 37, 41,  3, 41, 20,
#         2, 32, 39, 38, 32, 33, 32, 38, 14, 38, 39, 22, 47, 38, 25, 30, 33,
#        46,  2, 14, 46, 39, 38, 14, 38, 43, 34, 49, 11, 44,  1, 26, 38, 34,
#        42, 19, 44, 16, 38, 12, 49, 25, 39, 48, 38, 24, 14,  9, 48,  4, 32,
#        33, 38,  8, 39, 20, 38, 25, 34, 10, 47, 29, 11, 38, 19,  6, 38, 11,
#        38, 35, 37, 48, 19, 34,  9, 31, 39, 33, 43, 26, 32, 34, 28, 42, 48,
#        42, 43, 19, 34, 47, 40, 14, 42, 27, 37, 15, 35, 42, 42, 22, 16, 25,
#        43, 18, 28, 27, 38, 14, 38, 34, 42, 28, 27, 43, 42, 16, 18, 42, 21,
#        34, 16, 17, 27, 43, 17, 44, 42, 38, 20, 40,  4, 43, 18, 43, 33, 42,
#        34, 40, 43, 37, 40, 27, 38, 23,  7, 40,  0, 42, 47, 21, 18, 16, 49,
#        43, 16, 43, 27, 28, 42, 40, 18, 36,  1, 35, 40, 29, 26, 17, 25, 26,
#        17, 40, 16, 42, 13, 34, 12, 13, 34, 25, 48, 33, 33, 47, 38, 13, 10,
#        13, 47, 48, 33, 34, 38, 26, 29, 29, 29, 39, 19,  1, 12, 38, 15,  8,
#        35, 41, 16, 38, 41, 13, 35, 36, 47, 47, 47], dtype=int32)

# %%
df_clean['class'] = km.labels_
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Derive some clusterization parameters

# %%
km.inertia_
# Out:
# 0.12960449689522138

# %%
km.score(df_clean[['lat','lng']])
# Out:
# -0.1296044968952213

# %% [markdown]
# ## Plot a map of clusters

# %%
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, cluster in zip(df_clean['lat'], df_clean['lng'], df_clean['class']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
# add markers to map
for i, lat, lng, name in zip(venues.index, venues['lat'], venues['lng'], venues['name']):
    label = '{}: {}'.format(i, name.split("(")[0])
    
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_clusters)             
        
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
metro = venues
metro2 = venues
df_clean.dtypes
df_clean = df_clean.astype({'lat': 'float64', 'lng': 'float64'})
df_clean.dtypes
# Out:
# global_id           int64
# MainFunctional     object
# AdmArea            object
# lng               float64
# lat               float64
# class               int32
# dtype: object

# %% [markdown]
# ## Calculate Haversine distance between two points
# ### (Earth sphericity can be negligible within particular city so Euclidean distance can be used instead)

# %%
from sklearn.metrics.pairwise import haversine_distances
from math import radians

# %%
num = []
dist = []
for st in metro.index:
    count = 0
    loc_dist = []
    for prop in df_clean.index: #['class']:
        if st == df_clean.loc[prop, 'class']:
            count+=1
            #print("{}:{}".format(metro.iloc[st,'lat'], df_clean.loc[st,'lat']))
            #print("{} {} {} {}".format(metro.loc[st,'lng'], metro.loc[st,'lat'], df_clean.loc[prop,'lng'], df_clean.loc[prop,'lat']))
            #loc_dist.append(haversine(metro.loc[st,'lng'], metro.loc[st,'lat'], df_clean.loc[st,'lng'], df_clean.loc[st,'lat']))
            #metro.loc[st,'lat']-df_clean.loc[st,'lat'])
            mtr = [metro.loc[st,'lat'], metro.loc[st,'lng']]
            pty = [df_clean.loc[prop,'lat'], df_clean.loc[prop,'lng']]
            mtr_rad = [radians(_) for _ in mtr]
            pty_rad = [radians(_) for _ in pty]
            result = haversine_distances([mtr_rad, pty_rad])[0,1]
            loc_dist.append(result*6371000/1000)
    
    num.append(count)
    dist.append(loc_dist)
#print(num)
#print(dist)
metro['NumOfProp'] = num
metro['Distance'] = dist

# %%
metro.head()
# Out:
#                                                 name        lat        lng  \
# 0              metro Kitay-gorod (Метро Китай-город)  55.755196  37.633110
# 1  metro Taganskaya, line 5 (Метро Таганская, кол...  55.742171  37.653771
# 2                     metro Rimskaya (Метро Римская)  55.746339  37.681594
# 3  metro Komsomolskaya, line 5 (Метро Комсомольск...  55.775596  37.654834
# 4              metro Park Pobedy (Метро Парк Победы)  55.737146  37.515340
#
#    NumOfProp                                           Distance
# 0          7  [2.646517111137309, 2.2291379979156507, 4.0051...
# 1          6  [0.9721151917538717, 2.605395946545784, 1.0677...
# 2          4  [2.3026298947430797, 3.3592437443124883, 2.966...
# 3          1                               [0.5191717321156526]
# 4          3  [0.650341560180945, 1.3758639619849287, 2.2287...

# %% [markdown]
# ## Calculate number of buildings within a cluster

# %%
fig0 = plt.figure(figsize=(17,8))
#clust_size = sns.barplot(data=metro.loc[metro.index, 'NumOfProp'])

clust_size = metro.loc[metro.index,'NumOfProp']
clust_size.plot(kind='bar')
plt.title('')
plt.xlabel('Clusters')
plt.ylabel('Number of buildings')

#clust_size.set_ylabel('Distance (km)')
#xticklabels=range(0,50)
#clust_size.set_xticklabels(xticklabels)
fig0.show()
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   del sys.path[0]

# %%
print('Average number of buildings in a cluster: {} +/- {}'.format(clust_size.mean(), clust_size.std()))
# Out:
# Average number of buildings in a cluster: 9.06 +/- 6.723124880832224

# %% [markdown]
# ## Plot a distince distribution between buildings and metro stations

# %%
import seaborn as sns
fig1 = plt.figure(figsize=(17,10))
ax = sns.boxplot(data=metro['Distance'])
ax.set_title('')
ax.set_xlabel('Clusters')
ax.set_ylabel('Distance (km)')
xticklabels=range(0,50)
ax.set_xticklabels(xticklabels)
fig1.get_axes()[0].set_yscale('log')
fig1.show()
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# ## Perform clasterization with random initialization

# %%
kclusters = 50
km2 = KMeans(n_clusters=kclusters, init='random', max_iter=100, n_init=100, verbose=1)
km2.fit(df_clean2[['lat','lng']])
# Out:
# Initialization complete
# Iteration 0, inertia 0.5359081965850357
# Iteration 1, inertia 0.18611576674736735
# Iteration 2, inertia 0.17155758460669907
# Iteration 3, inertia 0.15782715630621702
# Iteration 4, inertia 0.1457399764323629
# Iteration 5, inertia 0.14402866978215087
# Iteration 6, inertia 0.14350790908366057
# Iteration 7, inertia 0.14329093250983407
# Iteration 8, inertia 0.14300637309237807
# Iteration 9, inertia 0.14296366057085635
# Converged at iteration 9: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.5592139067758739
# Iteration 1, inertia 0.17889817324402685
# Iteration 2, inertia 0.15073674189656325
# Iteration 3, inertia 0.1360641566348096
# Iteration 4, inertia 0.1278804437208165
# Iteration 5, inertia 0.12581428302041692
# Iteration 6, inertia 0.1245420856358957
# Iteration 7, inertia 0.12426896485683771
# Iteration 8, inertia 0.12419201303374727
# Converged at iteration 8: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.5071270758475799
# Iteration 1, inertia 0.16629876399798899
# Iteration 2, inertia 0.1362356441738054
# Iteration 3, inertia 0.126918184412137
# Iteration 4, inertia 0.12217509434592844
# Iteration 5, inertia 0.1187315125089575
# Iteration 6, inertia 0.11602181949360489
# Iteration 7, inertia 0.11544808380396303
# Iteration 8, inertia 0.1151424815394901
# Iteration 9, inertia 0.11480634771454525
# Iteration 10, inertia 0.11473508509987038
# Converged at iteration 10: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0
center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.3482701991883038
# Iteration 1, inertia 0.16854574274535108
# Iteration 2, inertia 0.14471995644886257
# Iteration 3, inertia 0.13336010803847495
# Iteration 4, inertia 0.12608755369315006
# Iteration 5, inertia 0.12435446632972952
# Iteration 6, inertia 0.12349228404772448
# Converged at iteration 6: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.3562805211956663
# Iteration 1, inertia 0.15490653306136007
# Iteration 2, inertia 0.1253771544486073
# Iteration 3, inertia 0.11513230026079214
# Iteration 4, inertia 0.11336518686039702
# Iteration 5, inertia 0.11301880626258688
# Converged at iteration 5: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.4054159253522347
# Iteration 1, inertia 0.19835619350164344
# Iteration 2, inertia 0.15944451283494004
# Iteration 3, inertia 0.1510444962894343
# Iteration 4, inertia 0.14788472118037074
# Iteration 5, inertia 0.14294252283427825
# Iteration 6, inertia 0.14171560806096187
# Iteration 7, inertia 0.14148792114978745
# Converged at iteration 7: center shift 0.0 within tolerance 1.1735382298696006e-06
# Initialization complete
# Iteration 0, inertia 0.3280216448785781
# Iteration 1, inertia 0.17758069106277768
# Iteration 2, inertia 0.13985517765161332
# Iteration 3, inertia 0.13396752167889903
# Iteration 4, inertia 0.1315772921862186
# Iteration 5, inertia 0.12773379245821362
# Iteration 6, inertia 0.1274449626621539
# Converged at iteration 6: center shift 0.0 within tolerance 1.1735382298696006e-06
# KMeans(init='random', max_iter=100, n_clusters=50, n_init=100, verbose=1)

# %%
km2.labels_
# Out:
# array([18, 44,  9, 17, 35, 24, 44, 10, 27, 26,  6,  4, 44, 37, 23, 12, 44,
#        47,  4, 26, 44, 35, 44, 18, 44, 44, 44, 44,  8,  4,  6, 40, 26, 29,
#        17, 33, 33, 21, 21, 21, 33, 26, 32, 20,  8, 37, 46,  3, 37, 33, 39,
#        32,  4, 35, 39, 26, 49,  1,  4, 12, 29, 37,  5,  2, 47, 32, 47,  6,
#         1, 27, 47,  6, 47, 43, 40, 12, 31,  4,  6,  6,  6, 33, 47,  4, 36,
#        45, 47, 23, 16, 30, 34, 31, 29,  1, 10, 10,  8,  3, 38, 10, 47, 38,
#         8, 16, 12, 34, 16,  2, 41, 41, 45, 16, 41, 41, 16,  8, 34, 34, 34,
#        33, 47, 39, 12,  7, 41, 36,  2, 33, 41, 30,  8, 33, 27,  8, 23, 10,
#        10, 25, 45, 19, 35,  2, 30, 35,  8, 31, 16, 12, 29, 35, 23, 49, 45,
#        10, 20, 16, 27, 10, 31, 16, 37, 33, 19, 29, 28, 45, 37, 37,  2, 20,
#        18,  8, 28, 47, 11, 16,  8, 29, 32, 19, 16, 14,  3, 10, 23, 29, 39,
#         8, 16,  7, 29, 19, 38, 41, 16, 45, 45,  8,  1, 11, 21, 16, 25, 16,
#        41, 42, 45,  1, 32, 30, 20, 32, 49, 17, 41, 14, 28, 28, 45,  8, 43,
#         3, 26, 26,  8, 42, 35, 14, 17, 14, 47,  8, 14,  2, 28, 47, 28,  3,
#        49, 19, 21, 16,  1, 30,  1, 16, 10, 14, 21,  3, 20, 16, 41,  3, 11,
#         7, 49, 10,  7, 21, 16, 10, 16, 29, 27, 47, 12, 39,  8, 23, 16, 27,
#        40, 20, 33, 34, 16, 37, 47, 41, 21, 34, 16, 37, 10,  3, 34, 33, 48,
#        30, 16, 31, 21,  3, 16, 41, 27,  8, 20, 22, 12, 14, 17, 26, 16, 12,
#        16, 25,  2, 35, 17, 39, 26,  4, 21, 30, 29, 23, 19, 27, 46, 40, 34,
#        40, 29, 17, 27, 20,  9, 10, 25, 15,  2, 45, 25, 40, 40,  3, 34, 43,
#        29, 13, 46, 15, 16, 10, 16, 27, 40, 40, 18, 29, 40, 20, 13, 40, 49,
#        39, 34, 18, 15, 16, 29, 39, 46, 16, 17,  0, 48, 29, 13, 29, 30, 40,
#        27, 44, 29,  2,  9, 18, 16, 42, 22,  9,  8, 40, 43, 36, 13, 34, 47,
#        29, 34, 29, 15, 46, 40,  0, 13, 35,  8, 25,  5, 38, 23, 18, 43, 23,
#        29,  5, 34, 46, 36, 27, 37, 36, 17, 41, 34, 30, 30, 20, 14, 36,  8,
#        36, 20, 35, 11, 39, 14, 23, 22, 22, 22, 21, 17,  8, 37, 14, 45, 31,
#        25, 28, 34, 16, 28, 36, 25, 34, 20, 20, 20], dtype=int32)

# %%
df_clean2['class'] = km2.labels_
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_clean2
# Out:
#       global_id                    MainFunctional  \
# 0     272726711  Многоэтажный многоквартирный дом
# 1     272726777  Многоэтажный многоквартирный дом
# 2     272726846  Многоэтажный многоквартирный дом
# 3     272726887  Многоэтажный многоквартирный дом
# 4     272726890  Многоэтажный многоквартирный дом
# ..          ...                               ...
# 448  1035998832  Многоэтажный многоквартирный дом
# 449  1037160508  Многоэтажный многоквартирный дом
# 450  1037862689  Многоэтажный многоквартирный дом
# 451  1037862798  Многоэтажный многоквартирный дом
# 452  1037862817  Многоэтажный многоквартирный дом
#
#                                 AdmArea              lng              lat  \
# 0    [Восточный административный округ]  37.795564262836  55.761349247059
# 1        [Южный административный округ]  37.662497752668  55.606339142276
# 2        [Южный административный округ]  37.677879903019  55.642152231422
# 3     [Северный административный округ]  37.500611345616  55.801860524702
# 4     [Северный административный округ]  37.561879230614  55.879979804897
# ..                                  ...              ...              ...
# 448      [Южный административный округ]  37.609481885433  55.673467591528
# 449   [Северный административный округ]  37.539289973813  55.840327725186
# 450   [Северный административный округ]  37.474834237220  55.859468813591
# 451   [Северный административный округ]  37.474834237220  55.859468813591
# 452   [Северный административный округ]  37.474834237220  55.859468813591
#
#      class
# 0       18
# 1       44
# 2        9
# 3       17
# 4       35
# ..     ...
# 448     25
# 449     34
# 450     20
# 451     20
# 452     20
#
# [453 rows x 6 columns]

# %%
km2.inertia_
# Out:
# 0.10234265319447874

# %% [markdown]
# ## Plot found clusters on a map

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, cluster in zip(df_clean2['lat'], df_clean2['lng'], df_clean2['class']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
# add markers to map
for i, lat, lng, name in zip(venues.index, venues['lat'], venues['lng'], venues['name']):
    label = '{}: {}'.format(i, name.split("(")[0])
    
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_clusters)             
        
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
